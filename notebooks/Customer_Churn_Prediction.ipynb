# %% [markdown]
# # Customer Churn Prediction System
# End-to-end workflow: data generation/loading → preprocessing → feature selection → classification → evaluation → model saving.

# %%
# %run ../src/train_model.py

# %% [markdown]
# ## Interactive Interface
# Run `streamlit run app.py` from the project root to use the prediction interface.

# %%
import pandas as pd
df=pd.read_csv('../data/customer_churn.csv')
df.head()

# %%
df.describe(include='all').T
